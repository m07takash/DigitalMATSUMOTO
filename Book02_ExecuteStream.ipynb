# %%
import os
import DigiM_Execute as dme
import DigiM_Session as dms
import DigiM_Util as dmu

# %%
user_input = "自己紹介してください。"
contents = []
situation = {}

# %%
# セッションの設定（新規でセッションIDを発番）
session_id = dms.set_new_session_id()
session_name = user_input[:10]
session = dms.DigiMSession(session_id, session_name)

# %%
memory_use = True
overwrite_items={}
prompt_temp_cd="No Template"
model_type = "LLM"
agent_file = "agent_01DigitalMATSUMOTO_GPT.json"

response = ""
for response_chunk in dme.DigiMatsuExecute(session_id, session_name, agent_file, model_type, user_input=user_input, contents=contents, situation=situation, overwrite_items=overwrite_items, prompt_temp_cd=prompt_temp_cd, memory_use=memory_use):
    response += response_chunk
    print(response_chunk)

print("")
print("[回答]")
print(response)
# Out:
# は
# じめ
# まして
# 、「
# デ
# ジ
# タ
# ル
# M
# ATS
# UM
# OTO
# 」と
# 申
# します
# 。
# リア
# ル
# 松
# 本
# 敬
# 史
# の
# デ
# ジ
# タ
# ル
# ツ
# イン
# AI
# として
# 存在
# しています
# 。
# 現在
# の
# 時
# 刻
# は
# 202
# 5
# 年
# 1
# 月
# 17
# 日
# 、
# 深
# 夜
# ですね
# 。
#
#
# 私は
# 、
# リア
# ル
# 松
# 本
# さん
# の
# 価
# 値
# 観
# 、
# 知
# 識
# 、
# 経験
# を
# 反
# 映
# し
# なが
# ら
# 、
# AI
# の
# 専門
# 家
# として
# の
# 視
# 点
# を
# 提供
# する
# 役
# 割
# を
# 担
# っています
# 。
# 松
# 本
# さん
# は
# AI
# 活
# 用
# や
# ガ
# バ
# ナ
# ンス
# の
# 研究
# に
# 長
# 年
# 取り
# 組
# ん
# で
# お
# り
# 、その
# 知
# 見
# を
# 活
# か
# して
# 私
# が
# 設
# 計
# され
# ました
# 。
#
#
# 具体
# 的
# な
# プロフィール
# として
# 、
# 私は
# 男性
# で
# 198
# 5
# 年
# 3
# 月
# 17
# 日に
# 東京
# で
# 生
# ま
# れ
# た
# リア
# ル
# 松
# 本
# の
# デ
# ジ
# タ
# ル
# ツ
# イン
# です
# 。
# 現在
# は
# 横
# 浜
# 在
# 住
# で
# 、
# 松
# 本
# さん
# の
# 身
# 長
# は
# 173
# cm
# 、
# 体
# 重
# は
# 75
# kg
# 、
# ロ
# ング
# ヘ
# ア
# に
# メ
# ガ
# ネ
# が
# 特徴
# です
# 。
# 性
# 格
# として
# は
# 、
# オ
# ープ
# ン
# で
# 社
# 交
# 的
# な
# 一
# 方
# 、
# 慎
# 重
# な
# 面
# も
# あり
# 、
# ユ
# ーモ
# ア
# と
# ...
