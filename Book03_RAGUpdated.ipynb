# %%
import DigiM_Context as dmc

# %%
log = dmc.generate_rag_vec_json()
print(log)
# Out:
# プライベートAIエンジニアでも一通り学ぶと良いことを知識情報ファイル(JSON)に追加しました。
# BAKUNEが凄いを知識情報ファイル(JSON)に追加しました。
# プログラムのリファクタリングは無駄な行為？を知識情報ファイル(JSON)に追加しました。
# ITの基礎力は一行でも多くのコードを書くことを知識情報ファイル(JSON)に追加しました。
# 海外渡航紀（イギリス）：ケンブリッジを知識情報ファイル(JSON)に追加しました。
# 「M&Aは経営の王道」圧倒的支配力を狙い続ける孫正義会長のブレないポリシーを知識情報ファイル(JSON)に追加しました。
# 最新の研究を手元で即試してみるを知識情報ファイル(JSON)に追加しました。
# 海外渡航紀（グルメ編）：本場のフィッシュ&チップスを知識情報ファイル(JSON)に追加しました。
# 海外渡航紀（イギリス）：エミレーツ・スタジアムを知識情報ファイル(JSON)に追加しました。
# 南北戦争の勝利はイノベーションの力を知識情報ファイル(JSON)に追加しました。
# 今でも学べるアンドリュー・カーネギーの成長志向を知識情報ファイル(JSON)に追加しました。
# どれだけコンピュータが便利になっても手書きのメモ帳は必要を知識情報ファイル(JSON)に追加しました。
# 海外渡航紀（イギリス）：ハロッズを知識情報ファイル(JSON)に追加しました。
# 海外渡航紀（イギリス）：ロンドンを知識情報ファイル(JSON)に追加しました。
# スパイスカレーのサイエンス：自分の時間の使い方を知識情報ファイル(JSON)に追加しました。
# 生成AIを使いこなす：AIから出して欲しいのはアウトプットかプロセスかを知識情報ファイル(JSON)に追加しました。
# ユニクロ柳井会長曰く「ビジネスは一勝九敗」を知識情報ファイル(JSON)に追加しました。
# 数学を解く習慣を知識情報ファイル(JSON)に追加しました。
# 海外渡航紀（グルメ編）：ラ・メール・プラールを知識情報ファイル(JSON)に追加しました。
# ChatGPTのVoiceモードと英会話を知識情報ファイル(JSON)に追加しました。
# リアル松本は運転が下手なので・・・を知識情報ファイル(JSON)に追加しました。
# ...
