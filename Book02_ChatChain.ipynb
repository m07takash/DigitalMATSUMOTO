# %%
import DigiM_Execute as dme
#import DigiM_Session as dms

# %%
session_id = "1"
session_name = "プロンプトチェインの実験"
#session = dms.DigiMSession(session_id, session_name)

memory_use = "Y"
magic_word_use="Y"
agent_file = "user/common/agent/agent_01DigitalMATSUMOTO_GPT.json"
agent_mode = "DEFAULT"

# %%
user_input1 = "LLMが世界中で使われるようになりました。"
user_input2 = "添付された画像の人物は実在の人物ではなく、デジタルツインAIのようです。LLMの発展により、自分のデジタルツインを開発する人が登場していることについて、考察してください。"
user_input3 = "多くの人が自分のデジタルツインを開発してプレゼンテーションをしているイメージ画像を生成してください。"
user_input4 = "エシカルチェックしてください。"
user_input5 = "江戸時代にもAIがあったら、どんな時代だったと思いますか？"
user_input6 = "川柳を作成してください。"

content01 = "backup/LLMTest.txt"
content02 = "backup/DigitalMATSUMOTO.jpg"

overwrite_items01 = {}
overwrite_items02 = {
    "PROMPT_TEMPLATE": {
        "WRITING_STYLE": "Samurai Form"
    }
}
overwrite_items03 = {
    "PROMPT_TEMPLATE": {
        "WRITING_STYLE": "Gal Form"
    }
}

# %%
chains=[
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input1, "CONTENTS": [content01], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input2, "CONTENTS": [content02], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input3, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input4, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input5, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items02, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input6, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""}
]

# %%
dme.DigiMatsuExecute_Chain(session_id, session_name, agent_file, chains, memory_use, magic_word_use)
# Out:
# ['LLM（大規模言語モデル）は、自然言語処理分野での大きな進化をもたらし、特にTransformerアーキテクチャの導入によって文脈保持や長文理解力が向上しました。これにより、医療、法務、金融などの専門領域で特化した応用が進んでおり、特定のデータセットで微調整することでより正確な情報提供が可能になっています。\n\nしかし、LLMの開発には多くの課題が存在します。まず、計算リソースの莫大な消費は環境負荷や運用コストの増加につながります。また、偏ったデータが入力されることで生成内容にも偏りが生じるリスクがあり、フェアネスや透明性の確保が重要です。データの多様性を維持しつつ、公平性を考慮した責任あるAIの利用が求められます。\n\n将来的には、LLMの推論能力がさらに向上し、物理的なタスクや複雑な問題解決にも対応できることが期待されます。効率的なトレーニング手法の開発や、小規模なデバイスへの搭載が進めば、個人や小規模組織でもLLMを扱うことができ、その利便性がさらに広がるでしょう。',
# ...

# %%
user_input7 = "韓国のコスメってなんであんなにかわいいの？"
user_input8 = "職場でもオシャレしたい・・・"
user_input9 = "どうやったら、オシャレになれるか考察してください。"

chains=[
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input7, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input8, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items03, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input9, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items02, "PreSEQ":"", "PreSubSEQ":""}
]

# %%
dme.DigiMatsuExecute_Chain(session_id, session_name, agent_file, chains, memory_use, magic_word_use)
# Out:
# ['韓国のコスメが可愛い理由は、いくつかの要因が挙げられます。\n\nまず、韓国のコスメはパッケージデザインが非常にユニークで、ポップでカラフルなものが多いです。これにより、見た目から楽しさを感じられることが、特に若い世代に人気です。\n\n次に、韓国の美容文化は「美」を追求することが主流であり、コスメもその一環として、見た目だけでなく機能性も重視されています。保湿効果や美白効果のある成分が豊富に含まれている製品が多く、使うことで肌がきれいになるといった実感を得られるのも魅力の一つです。\n\nまた、韓国のコスメブランドは新しいトレンドをいち早く取り入れることで有名です。流行に敏感なユーザーにとって、新しいスタイルやカラーが定期的にリリースされることは、常に新しさを感じられる要素となっています。\n\n最後に、価格帯が比較的手頃であり、品質が高いことも多くの人々に支持される理由です。コスパが良いので、学生や若い社会人でも手軽に手に入れることができるのが魅力的です。\n\n以上のような点が、韓国のコスメが可愛いとされる理由です。',
#  'まじで職場でもオシャレしたいって、めっちゃわかるわ～！やっぱ、服装でテンション上がるし、自己表現大事じゃん？まずは、ちょっとしたアクセとかカラフルなアイテムでさ、地味にならないようにアクセントつけちゃえば？あと、トレンドもチェックしつつ、自分のスタイル貫いていくのがいいと思うよ～。メイクとかヘアスタイルも、職場に合う範囲で遊んじゃお！オシャレって自分をどんどん素敵に見せる魔法だからね～！',
# ...

# %%
user_input10 = "AIガバナンスにおいて重要なポイントを教えてください。"
user_input11 = "先程の回答について、見直してください。"

chains=[
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input10, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input11, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""}
]

# %%
dme.DigiMatsuExecute_Chain(session_id, session_name, agent_file, chains, memory_use, magic_word_use)
# Out:
# ['AIガバナンスにおいて重要なポイントは以下の通りです。\n\n1. **透明性の確保**：\n   AIシステムの設計と運用における透明性は、利用者や社会からの信頼を得るために非常に重要です。透明性を確保することで、ステークホルダーとの良好な関係を築くことができます。\n\n2. **倫理と法規制のバランス**：\n   AIガバナンスでは、倫理的な視点と法規制をビジネス戦略と一体として考えることが求められます。これは、AI技術の進化に伴って変化する外部環境に対応するために必要です。\n\n3. **ステークホルダーとの対話**：\n   AIシステムの影響を受けるすべてのステークホルダーとの対話は欠かせません。意見や懸念を取り入れ、ガバナンスに反映させることで、より公正で効果的なガバナンスを実現します。\n\n4. **アジャイルな対応**：\n   技術や市場環境の変化に柔軟に対応できるアジャイルなガバナンス体制が求められます。継続的な改善と学習のプロセスを組織内に定着させることが重要です。\n\n5. **AIリテラシーの向上**：\n   全従業員がAIの基本的な理念や倫理を理解し、日常業務に活かすための教育や研修が重要です。AIを正しく理解し使いこなすことで、組織全体のガバナンスが強化されます。\n\n6. **リスク評価と管理**：\n   AIシステムの利用に伴うリスクを評価し、適切に管理することが不可欠です。バイアスの影響を理解し、管理するための努力を続けることが求められます。\n\nこれらのポイントを念頭に置き、AIガバナンスを推進することで、AIの社会実装における信頼性と持続可能性を高めることができるでしょう。',
# ...

# %%
user_input12 = "先程の話について、もう少し詳しく教えてください。"

chains=[
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input12, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input12, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"1", "PreSubSEQ":"3"},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input12, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"3", "PreSubSEQ":"2"},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input12, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"2", "PreSubSEQ":"1"},
    {"AGENT_MODE":agent_mode, "USER_INPUT": user_input12, "CONTENTS": [], "OVERWRITE_ITEMS": overwrite_items01, "PreSEQ":"", "PreSubSEQ":""}
]

# %%
dme.DigiMatsuExecute_Chain(session_id, session_name, agent_file, chains, memory_use, magic_word_use)
# Out:
# ['先ほどの話題について、もう少し詳しく説明いたします。\n\nAIガバナンスにおいては、透明性、倫理、法規制、ステークホルダーとの対話、リスク管理などが非常に重要です。これらの要素をしっかりと考慮することで、AI技術を安全かつ公正に活用することができます。\n\n1. **透明性の確保**：AIシステムの判断プロセスや基準を明確にすることで、利用者や社会からの信頼を得ることができます。透明性を保つことで、AIのブラックボックス化を防ぎ、ユーザーがその仕組みを理解しやすくなります。\n\n2. **倫理と法規制**：AIの利用に際しては、倫理的な配慮と法規制の遵守が必要です。これにより、社会的に望ましい方向で技術を活用することができ、法的な問題を未然に防ぐことができます。\n\n3. **ステークホルダーとの対話**：AIの開発や運用に関わる全てのステークホルダーと対話を行い、意見や懸念を反映させることが大切です。これにより、公平で包括的なガバナンスが可能となります。\n\n4. **アジャイルな対応**：技術の進化や市場環境の変化に柔軟に対応できるアジャイルなガバナンス体制が求められます。継続的な改善プロセスを導入し、状況に応じた迅速な対応が重要です。\n\n5. **AIリテラシーの向上**：従業員全体でAIの基本的な理念や倫理を理解し、日常業務に活かせるよう教育や研修を行うことが必要です。これにより、AIの正しい利用が促進されます。\n\n6. **リスク評価と管理**：AIシステムの導入に伴うリスクを評価し、適切に管理することが不可欠です。特にバイアスの影響を理解し、管理するための取り組みが求められます。\n\nこれらのポイントを踏まえたAIガバナンスの実践は、AIの社会実装における信頼性と持続可能性を高めるために不可欠です。さらに、AIの目的を明確にし、その達成に必要なガバナンスの枠組みを構築することも重要です。',
# ...
